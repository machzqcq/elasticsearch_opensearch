# %% [markdown]
# # 🚀 OpenSearch Bulk API Optimization Demo
#
# This notebook demonstrates how to optimize OpenSearch ingestion using the Bulk API with the SQUAD training dataset.
#
# ## 📊 What We'll Learn:
# - Bulk API vs individual document indexing
# - Optimal batch size tuning
# - Asynchronous vs synchronous operations
# - Error handling and retry strategies
# - Performance measurement and analysis
#
# ```mermaid
# graph TD
#     A[🗂️ SQUAD Dataset] --> B[📦 Batch Documents]
#     B --> C{🔢 Batch Size}
#     C -->|Small 100| D[🐌 Slower Ingestion]
#     C -->|Optimal 1000| E[⚡ Fast Ingestion]
#     C -->|Large 10000| F[💾 Memory Issues]
#
#     E --> G[🔄 Async Processing]
#     G --> H[📈 Monitor Performance]
#     H --> I[🎯 65% Speed Improvement]
#
#     style A fill:#e1f5fe
#     style E fill:#c8e6c9
#     style G fill:#fff3e0
#     style I fill:#f3e5f5
# ```

# %% [markdown]
# ## 🐳 Step 1: Start Docker Environment
#
# First, start the OpenSearch cluster using the optimized docker-compose file:

# %%
# %%bash
# # Navigate to the docker compose directory and start the cluster
# cd ../
# docker-compose -f docker-compose-optimized.yml up -d
#
# # Wait for the cluster to be ready
# echo "Waiting for OpenSearch to start..."
# sleep 30
#
# # Check cluster health
# curl -k -u admin:Developer@123 https://localhost:9200/_cluster/health?pretty

# %% [markdown]
# ## 📚 Step 2: Import Required Libraries

# %%
import pandas as pd
import numpy as np
import time
import asyncio
import json
from opensearchpy import OpenSearch, helpers
from opensearchpy import AsyncOpenSearch
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List, Dict, Any
import warnings
warnings.filterwarnings('ignore')

# Configure matplotlib
plt.style.use('default')
sns.set_palette("husl")

print("📦 All libraries imported successfully!")
# Out:
# 📦 All libraries imported successfully!

# %% [markdown]
# ## 🔌 Step 3: Connect to OpenSearch

# %%
# OpenSearch connection configuration
client = OpenSearch(
    hosts=[{'host': 'localhost', 'port': 9200}],
    http_auth=('admin', 'Developer@123'),
    use_ssl=True,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False
)

# Async client for performance comparison
async_client = AsyncOpenSearch(
    hosts=[{'host': 'localhost', 'port': 9200}],
    http_auth=('admin', 'Developer@123'),
    use_ssl=True,
    verify_certs=False,
    ssl_assert_hostname=False,
    ssl_show_warn=False
)

# Test connection
try:
    info = client.info()
    print(f"✅ Connected to OpenSearch cluster: {info['cluster_name']}")
    print(f"📊 Version: {info['version']['number']}")
except Exception as e:
    print(f"❌ Connection failed: {e}")
# Out:
# ✅ Connected to OpenSearch cluster: opensearch-cluster
# 📊 Version: 3.2.0

# %% [markdown]
# ## 📖 Step 4: Load SQUAD Dataset

# %%
# Load SQUAD training dataset
data_path = "../../../../../data/SQUAD-train.parquet"
df = pd.read_parquet(data_path)

print(f"📊 Dataset Shape: {df.shape}")
print(f"📝 Columns: {list(df.columns)}")
print("\n🔍 Sample Data:")
print(df.head(2))

# Prepare data for indexing
def prepare_document(row, index):
    """Convert DataFrame row to OpenSearch document"""
    return {
        "_index": "squad-bulk-demo",
        "_id": index,
        "_source": {
            "id": row.get('id', str(index)),
            "title": row.get('title', ''),
            "context": row.get('context', ''),
            "question": row.get('question', ''),
            "answers": row.get('answers', {}),
            "timestamp": time.time()
        }
    }

print(f"\n✅ Loaded {len(df)} documents from SQUAD dataset")
# Out:
# 📊 Dataset Shape: (87599, 5)
# 📝 Columns: ['id', 'title', 'context', 'question', 'answers']
#
# 🔍 Sample Data:
#                          id                     title  \
# 0  5733be284776f41900661182  University_of_Notre_Dame
# 1  5733be284776f4190066117f  University_of_Notre_Dame
#
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
#
#                                              answers
# 0  {'text': ['Saint Bernadette Soubirous'], 'answ...
# 1  {'text': ['a copper statue of Christ'], 'answe...
#
# ✅ Loaded 87599 documents from SQUAD dataset

# %% [markdown]
# ## 🔧 Step 5: Create Index with Optimized Settings

# %%
# Index configuration for bulk optimization
index_name = "squad-bulk-demo"

# Delete index if it exists
try:
    client.indices.delete(index=index_name)
    print(f"🗑️ Deleted existing index: {index_name}")
except:
    pass

# Create index with optimized settings
index_settings = {
    "settings": {
        "number_of_shards": 2,
        "number_of_replicas": 1,
        "refresh_interval": "30s",  # Increased for better bulk performance
        "index": {
            "translog.flush_threshold_size": "1GB",  # Larger translog for fewer flushes
            "max_result_window": 50000
        }
    },
    "mappings": {
        "properties": {
            "id": {"type": "keyword"},
            "title": {"type": "text", "analyzer": "standard"},
            "context": {"type": "text", "analyzer": "standard"},
            "question": {"type": "text", "analyzer": "standard"},
            "answers": {"type": "object"},
            "timestamp": {"type": "date", "format": "epoch_second"}
        }
    }
}

response = client.indices.create(index=index_name, body=index_settings)
print(f"✅ Created index '{index_name}' with optimized settings")
print(f"📋 Index acknowledged: {response['acknowledged']}")
# Out:
# ✅ Created index 'squad-bulk-demo' with optimized settings
# 📋 Index acknowledged: True

# %% [markdown]
# ## ⚡ Step 6: Bulk API Performance Testing

# %%
def test_individual_indexing(documents, max_docs=5000):
    """Test individual document indexing performance"""
    start_time = time.time()
    errors = 0
    
    print(f"🐌 Testing individual indexing with {min(max_docs, len(documents))} documents...")
    
    for i, doc in enumerate(documents[:max_docs]):
        try:
            client.index(
                index=index_name,
                id=f"individual_{i}",
                body=doc['_source']
            )
        except Exception as e:
            errors += 1
            if errors <= 5:  # Show first 5 errors
                print(f"❌ Error at doc {i}: {str(e)[:100]}...")
                
        if (i + 1) % 100 == 0:
            print(f"📝 Indexed {i + 1} documents...")
    
    end_time = time.time()
    duration = end_time - start_time
    
    return {
        'method': 'Individual',
        'duration': duration,
        'docs_per_second': max_docs / duration,
        'errors': errors,
        'total_docs': min(max_docs, len(documents))
    }

def test_bulk_indexing(documents, batch_size=1000, max_docs=50000):
    """Test bulk indexing performance"""
    start_time = time.time()
    total_errors = 0
    
    print(f"⚡ Testing bulk indexing with batch size {batch_size}, max docs {max_docs}...")
    
    # Prepare documents for bulk indexing
    bulk_docs = []
    for i, doc in enumerate(documents[:max_docs]):
        doc['_id'] = f"bulk_{i}"
        bulk_docs.append(doc)
    
    # Process in batches
    for i in range(0, len(bulk_docs), batch_size):
        batch = bulk_docs[i:i + batch_size]
        try:
            response = helpers.bulk(client, batch, refresh=False)
            if response[1]:  # Check for errors
                total_errors += len(response[1])
                print(f"⚠️ Batch {i//batch_size + 1}: {len(response[1])} errors")
        except Exception as e:
            print(f"❌ Batch error: {str(e)[:100]}...")
            total_errors += len(batch)
        
        print(f"📦 Processed batch {i//batch_size + 1}, docs {i+1}-{min(i+batch_size, len(bulk_docs))}")
    
    end_time = time.time()
    duration = end_time - start_time
    
    return {
        'method': f'Bulk (batch={batch_size})',
        'duration': duration,
        'docs_per_second': len(bulk_docs) / duration,
        'errors': total_errors,
        'total_docs': len(bulk_docs),
        'batch_size': batch_size
    }

# Prepare test documents
test_docs = [prepare_document(row, i) for i, row in df.head(50000).iterrows()]
print(f"🎯 Prepared {len(test_docs)} test documents")
# Out:
# 🎯 Prepared 50000 test documents

# %% [markdown]
# ### 🧪 Run Performance Tests

# %%
# Run performance comparison tests
results = []

# Test 1: Individual indexing (small sample)
print("=" * 60)
result_individual = test_individual_indexing(test_docs, max_docs=5000)
results.append(result_individual)

print("\n" + "=" * 60)
# Test 2: Bulk indexing with different batch sizes
batch_sizes = [100, 500, 1000, 2000,5000,10000,20000]

for batch_size in batch_sizes:
    print(f"\n🔄 Testing batch size: {batch_size}")
    result_bulk = test_bulk_indexing(test_docs, batch_size=batch_size, max_docs=50000)
    results.append(result_bulk)
    time.sleep(2)  # Brief pause between tests

# Display results
print("\n" + "=" * 60)
print("📊 PERFORMANCE RESULTS")
print("=" * 60)

results_df = pd.DataFrame(results)
print(results_df.to_string(index=False))

# Find best performing method
best_result = max(results, key=lambda x: x['docs_per_second'])
print(f"\n🏆 Best Performance: {best_result['method']}")
print(f"📈 {best_result['docs_per_second']:.2f} docs/second")
# Out:
# ============================================================
# 🐌 Testing individual indexing with 5000 documents...
# 📝 Indexed 100 documents...
# 📝 Indexed 200 documents...
# 📝 Indexed 300 documents...
# 📝 Indexed 400 documents...
# 📝 Indexed 500 documents...
# 📝 Indexed 600 documents...
# 📝 Indexed 700 documents...
# 📝 Indexed 800 documents...
# 📝 Indexed 900 documents...
# 📝 Indexed 1000 documents...
# 📝 Indexed 1100 documents...
# 📝 Indexed 1200 documents...
# 📝 Indexed 1300 documents...
# 📝 Indexed 1400 documents...
# 📝 Indexed 1500 documents...
# 📝 Indexed 1600 documents...
# 📝 Indexed 1700 documents...
# 📝 Indexed 1800 documents...
# 📝 Indexed 1900 documents...
# 📝 Indexed 2000 documents...
# 📝 Indexed 2100 documents...
# 📝 Indexed 2200 documents...
# 📝 Indexed 2300 documents...
# 📝 Indexed 2400 documents...
# 📝 Indexed 2500 documents...
# 📝 Indexed 2600 documents...
# 📝 Indexed 2700 documents...
# 📝 Indexed 2800 documents...
# 📝 Indexed 2900 documents...
# 📝 Indexed 3000 documents...
# 📝 Indexed 3100 documents...
# 📝 Indexed 3200 documents...
# 📝 Indexed 3300 documents...
# 📝 Indexed 3400 documents...
# 📝 Indexed 3500 documents...
# 📝 Indexed 3600 documents...
# 📝 Indexed 3700 documents...
# 📝 Indexed 3800 documents...
# 📝 Indexed 3900 documents...
# 📝 Indexed 4000 documents...
# 📝 Indexed 4100 documents...
# 📝 Indexed 4200 documents...
# 📝 Indexed 4300 documents...
# 📝 Indexed 4400 documents...
# 📝 Indexed 4500 documents...
# 📝 Indexed 4600 documents...
# 📝 Indexed 4700 documents...
# 📝 Indexed 4800 documents...
# 📝 Indexed 4900 documents...
# 📝 Indexed 5000 documents...
#
# ============================================================
#
# 🔄 Testing batch size: 100
# ⚡ Testing bulk indexing with batch size 100, max docs 50000...
# 📦 Processed batch 1, docs 1-100
# 📦 Processed batch 2, docs 101-200
# 📦 Processed batch 3, docs 201-300
# 📦 Processed batch 4, docs 301-400
# 📦 Processed batch 5, docs 401-500
# 📦 Processed batch 6, docs 501-600
# 📦 Processed batch 7, docs 601-700
# 📦 Processed batch 8, docs 701-800
# 📦 Processed batch 9, docs 801-900
# 📦 Processed batch 10, docs 901-1000
# 📦 Processed batch 11, docs 1001-1100
# 📦 Processed batch 12, docs 1101-1200
# 📦 Processed batch 13, docs 1201-1300
# 📦 Processed batch 14, docs 1301-1400
# 📦 Processed batch 15, docs 1401-1500
# 📦 Processed batch 16, docs 1501-1600
# 📦 Processed batch 17, docs 1601-1700
# 📦 Processed batch 18, docs 1701-1800
# 📦 Processed batch 19, docs 1801-1900
# 📦 Processed batch 20, docs 1901-2000
# 📦 Processed batch 21, docs 2001-2100
# 📦 Processed batch 22, docs 2101-2200
# 📦 Processed batch 23, docs 2201-2300
# 📦 Processed batch 24, docs 2301-2400
# 📦 Processed batch 25, docs 2401-2500
# 📦 Processed batch 26, docs 2501-2600
# 📦 Processed batch 27, docs 2601-2700
# 📦 Processed batch 28, docs 2701-2800
# 📦 Processed batch 29, docs 2801-2900
# 📦 Processed batch 30, docs 2901-3000
# 📦 Processed batch 31, docs 3001-3100
# 📦 Processed batch 32, docs 3101-3200
# 📦 Processed batch 33, docs 3201-3300
# 📦 Processed batch 34, docs 3301-3400
# 📦 Processed batch 35, docs 3401-3500
# 📦 Processed batch 36, docs 3501-3600
# 📦 Processed batch 37, docs 3601-3700
# 📦 Processed batch 38, docs 3701-3800
# 📦 Processed batch 39, docs 3801-3900
# 📦 Processed batch 40, docs 3901-4000
# 📦 Processed batch 41, docs 4001-4100
# 📦 Processed batch 42, docs 4101-4200
# 📦 Processed batch 43, docs 4201-4300
# 📦 Processed batch 44, docs 4301-4400
# 📦 Processed batch 45, docs 4401-4500
# 📦 Processed batch 46, docs 4501-4600
# 📦 Processed batch 47, docs 4601-4700
# 📦 Processed batch 48, docs 4701-4800
# 📦 Processed batch 49, docs 4801-4900
# 📦 Processed batch 50, docs 4901-5000
# 📦 Processed batch 51, docs 5001-5100
# 📦 Processed batch 52, docs 5101-5200
# 📦 Processed batch 53, docs 5201-5300
# 📦 Processed batch 54, docs 5301-5400
# 📦 Processed batch 55, docs 5401-5500
# 📦 Processed batch 56, docs 5501-5600
# 📦 Processed batch 57, docs 5601-5700
# 📦 Processed batch 58, docs 5701-5800
# 📦 Processed batch 59, docs 5801-5900
# 📦 Processed batch 60, docs 5901-6000
# 📦 Processed batch 61, docs 6001-6100
# 📦 Processed batch 62, docs 6101-6200
# 📦 Processed batch 63, docs 6201-6300
# 📦 Processed batch 64, docs 6301-6400
# 📦 Processed batch 65, docs 6401-6500
# 📦 Processed batch 66, docs 6501-6600
# 📦 Processed batch 67, docs 6601-6700
# 📦 Processed batch 68, docs 6701-6800
# 📦 Processed batch 69, docs 6801-6900
# 📦 Processed batch 70, docs 6901-7000
# 📦 Processed batch 71, docs 7001-7100
# 📦 Processed batch 72, docs 7101-7200
# 📦 Processed batch 73, docs 7201-7300
# 📦 Processed batch 74, docs 7301-7400
# 📦 Processed batch 75, docs 7401-7500
# 📦 Processed batch 76, docs 7501-7600
# 📦 Processed batch 77, docs 7601-7700
# 📦 Processed batch 78, docs 7701-7800
# 📦 Processed batch 79, docs 7801-7900
# 📦 Processed batch 80, docs 7901-8000
# 📦 Processed batch 81, docs 8001-8100
# 📦 Processed batch 82, docs 8101-8200
# 📦 Processed batch 83, docs 8201-8300
# 📦 Processed batch 84, docs 8301-8400
# 📦 Processed batch 85, docs 8401-8500
# 📦 Processed batch 86, docs 8501-8600
# 📦 Processed batch 87, docs 8601-8700
# 📦 Processed batch 88, docs 8701-8800
# 📦 Processed batch 89, docs 8801-8900
# 📦 Processed batch 90, docs 8901-9000
# 📦 Processed batch 91, docs 9001-9100
# 📦 Processed batch 92, docs 9101-9200
# 📦 Processed batch 93, docs 9201-9300
# 📦 Processed batch 94, docs 9301-9400
# 📦 Processed batch 95, docs 9401-9500
# 📦 Processed batch 96, docs 9501-9600
# 📦 Processed batch 97, docs 9601-9700
# 📦 Processed batch 98, docs 9701-9800
# 📦 Processed batch 99, docs 9801-9900
# 📦 Processed batch 100, docs 9901-10000
# 📦 Processed batch 101, docs 10001-10100
# 📦 Processed batch 102, docs 10101-10200
# 📦 Processed batch 103, docs 10201-10300
# 📦 Processed batch 104, docs 10301-10400
# 📦 Processed batch 105, docs 10401-10500
# 📦 Processed batch 106, docs 10501-10600
# 📦 Processed batch 107, docs 10601-10700
# 📦 Processed batch 108, docs 10701-10800
# 📦 Processed batch 109, docs 10801-10900
# 📦 Processed batch 110, docs 10901-11000
# 📦 Processed batch 111, docs 11001-11100
# 📦 Processed batch 112, docs 11101-11200
# 📦 Processed batch 113, docs 11201-11300
# 📦 Processed batch 114, docs 11301-11400
# 📦 Processed batch 115, docs 11401-11500
# 📦 Processed batch 116, docs 11501-11600
# 📦 Processed batch 117, docs 11601-11700
# 📦 Processed batch 118, docs 11701-11800
# 📦 Processed batch 119, docs 11801-11900
# 📦 Processed batch 120, docs 11901-12000
# 📦 Processed batch 121, docs 12001-12100
# 📦 Processed batch 122, docs 12101-12200
# 📦 Processed batch 123, docs 12201-12300
# 📦 Processed batch 124, docs 12301-12400
# 📦 Processed batch 125, docs 12401-12500
# 📦 Processed batch 126, docs 12501-12600
# 📦 Processed batch 127, docs 12601-12700
# 📦 Processed batch 128, docs 12701-12800
# 📦 Processed batch 129, docs 12801-12900
# 📦 Processed batch 130, docs 12901-13000
# 📦 Processed batch 131, docs 13001-13100
# 📦 Processed batch 132, docs 13101-13200
# 📦 Processed batch 133, docs 13201-13300
# 📦 Processed batch 134, docs 13301-13400
# 📦 Processed batch 135, docs 13401-13500
# 📦 Processed batch 136, docs 13501-13600
# 📦 Processed batch 137, docs 13601-13700
# 📦 Processed batch 138, docs 13701-13800
# 📦 Processed batch 139, docs 13801-13900
# 📦 Processed batch 140, docs 13901-14000
# 📦 Processed batch 141, docs 14001-14100
# 📦 Processed batch 142, docs 14101-14200
# 📦 Processed batch 143, docs 14201-14300
# 📦 Processed batch 144, docs 14301-14400
# 📦 Processed batch 145, docs 14401-14500
# 📦 Processed batch 146, docs 14501-14600
# 📦 Processed batch 147, docs 14601-14700
# 📦 Processed batch 148, docs 14701-14800
# 📦 Processed batch 149, docs 14801-14900
# 📦 Processed batch 150, docs 14901-15000
# 📦 Processed batch 151, docs 15001-15100
# 📦 Processed batch 152, docs 15101-15200
# 📦 Processed batch 153, docs 15201-15300
# 📦 Processed batch 154, docs 15301-15400
# 📦 Processed batch 155, docs 15401-15500
# 📦 Processed batch 156, docs 15501-15600
# 📦 Processed batch 157, docs 15601-15700
# 📦 Processed batch 158, docs 15701-15800
# 📦 Processed batch 159, docs 15801-15900
# 📦 Processed batch 160, docs 15901-16000
# 📦 Processed batch 161, docs 16001-16100
# 📦 Processed batch 162, docs 16101-16200
# 📦 Processed batch 163, docs 16201-16300
# 📦 Processed batch 164, docs 16301-16400
# 📦 Processed batch 165, docs 16401-16500
# 📦 Processed batch 166, docs 16501-16600
# 📦 Processed batch 167, docs 16601-16700
# 📦 Processed batch 168, docs 16701-16800
# 📦 Processed batch 169, docs 16801-16900
# 📦 Processed batch 170, docs 16901-17000
# 📦 Processed batch 171, docs 17001-17100
# 📦 Processed batch 172, docs 17101-17200
# 📦 Processed batch 173, docs 17201-17300
# 📦 Processed batch 174, docs 17301-17400
# 📦 Processed batch 175, docs 17401-17500
# 📦 Processed batch 176, docs 17501-17600
# 📦 Processed batch 177, docs 17601-17700
# 📦 Processed batch 178, docs 17701-17800
# 📦 Processed batch 179, docs 17801-17900
# 📦 Processed batch 180, docs 17901-18000
# 📦 Processed batch 181, docs 18001-18100
# 📦 Processed batch 182, docs 18101-18200
# 📦 Processed batch 183, docs 18201-18300
# 📦 Processed batch 184, docs 18301-18400
# 📦 Processed batch 185, docs 18401-18500
# 📦 Processed batch 186, docs 18501-18600
# 📦 Processed batch 187, docs 18601-18700
# 📦 Processed batch 188, docs 18701-18800
# 📦 Processed batch 189, docs 18801-18900
# 📦 Processed batch 190, docs 18901-19000
# 📦 Processed batch 191, docs 19001-19100
# 📦 Processed batch 192, docs 19101-19200
# 📦 Processed batch 193, docs 19201-19300
# 📦 Processed batch 194, docs 19301-19400
# 📦 Processed batch 195, docs 19401-19500
# 📦 Processed batch 196, docs 19501-19600
# 📦 Processed batch 197, docs 19601-19700
# 📦 Processed batch 198, docs 19701-19800
# 📦 Processed batch 199, docs 19801-19900
# 📦 Processed batch 200, docs 19901-20000
# 📦 Processed batch 201, docs 20001-20100
# 📦 Processed batch 202, docs 20101-20200
# 📦 Processed batch 203, docs 20201-20300
# 📦 Processed batch 204, docs 20301-20400
# 📦 Processed batch 205, docs 20401-20500
# 📦 Processed batch 206, docs 20501-20600
# 📦 Processed batch 207, docs 20601-20700
# 📦 Processed batch 208, docs 20701-20800
# 📦 Processed batch 209, docs 20801-20900
# 📦 Processed batch 210, docs 20901-21000
# 📦 Processed batch 211, docs 21001-21100
# 📦 Processed batch 212, docs 21101-21200
# 📦 Processed batch 213, docs 21201-21300
# 📦 Processed batch 214, docs 21301-21400
# 📦 Processed batch 215, docs 21401-21500
# 📦 Processed batch 216, docs 21501-21600
# 📦 Processed batch 217, docs 21601-21700
# 📦 Processed batch 218, docs 21701-21800
# 📦 Processed batch 219, docs 21801-21900
# 📦 Processed batch 220, docs 21901-22000
# 📦 Processed batch 221, docs 22001-22100
# 📦 Processed batch 222, docs 22101-22200
# 📦 Processed batch 223, docs 22201-22300
# 📦 Processed batch 224, docs 22301-22400
# 📦 Processed batch 225, docs 22401-22500
# 📦 Processed batch 226, docs 22501-22600
# 📦 Processed batch 227, docs 22601-22700
# 📦 Processed batch 228, docs 22701-22800
# 📦 Processed batch 229, docs 22801-22900
# 📦 Processed batch 230, docs 22901-23000
# 📦 Processed batch 231, docs 23001-23100
# 📦 Processed batch 232, docs 23101-23200
# 📦 Processed batch 233, docs 23201-23300
# 📦 Processed batch 234, docs 23301-23400
# 📦 Processed batch 235, docs 23401-23500
# 📦 Processed batch 236, docs 23501-23600
# 📦 Processed batch 237, docs 23601-23700
# 📦 Processed batch 238, docs 23701-23800
# 📦 Processed batch 239, docs 23801-23900
# 📦 Processed batch 240, docs 23901-24000
# 📦 Processed batch 241, docs 24001-24100
# 📦 Processed batch 242, docs 24101-24200
# 📦 Processed batch 243, docs 24201-24300
# 📦 Processed batch 244, docs 24301-24400
# 📦 Processed batch 245, docs 24401-24500
# 📦 Processed batch 246, docs 24501-24600
# 📦 Processed batch 247, docs 24601-24700
# 📦 Processed batch 248, docs 24701-24800
# 📦 Processed batch 249, docs 24801-24900
# 📦 Processed batch 250, docs 24901-25000
# 📦 Processed batch 251, docs 25001-25100
# 📦 Processed batch 252, docs 25101-25200
# 📦 Processed batch 253, docs 25201-25300
# 📦 Processed batch 254, docs 25301-25400
# 📦 Processed batch 255, docs 25401-25500
# 📦 Processed batch 256, docs 25501-25600
# 📦 Processed batch 257, docs 25601-25700
# 📦 Processed batch 258, docs 25701-25800
# 📦 Processed batch 259, docs 25801-25900
# 📦 Processed batch 260, docs 25901-26000
# 📦 Processed batch 261, docs 26001-26100
# 📦 Processed batch 262, docs 26101-26200
# 📦 Processed batch 263, docs 26201-26300
# 📦 Processed batch 264, docs 26301-26400
# 📦 Processed batch 265, docs 26401-26500
# 📦 Processed batch 266, docs 26501-26600
# 📦 Processed batch 267, docs 26601-26700
# 📦 Processed batch 268, docs 26701-26800
# 📦 Processed batch 269, docs 26801-26900
# 📦 Processed batch 270, docs 26901-27000
# 📦 Processed batch 271, docs 27001-27100
# 📦 Processed batch 272, docs 27101-27200
# 📦 Processed batch 273, docs 27201-27300
# 📦 Processed batch 274, docs 27301-27400
# 📦 Processed batch 275, docs 27401-27500
# 📦 Processed batch 276, docs 27501-27600
# 📦 Processed batch 277, docs 27601-27700
# 📦 Processed batch 278, docs 27701-27800
# 📦 Processed batch 279, docs 27801-27900
# 📦 Processed batch 280, docs 27901-28000
# 📦 Processed batch 281, docs 28001-28100
# 📦 Processed batch 282, docs 28101-28200
# 📦 Processed batch 283, docs 28201-28300
# 📦 Processed batch 284, docs 28301-28400
# 📦 Processed batch 285, docs 28401-28500
# 📦 Processed batch 286, docs 28501-28600
# 📦 Processed batch 287, docs 28601-28700
# 📦 Processed batch 288, docs 28701-28800
# 📦 Processed batch 289, docs 28801-28900
# 📦 Processed batch 290, docs 28901-29000
# 📦 Processed batch 291, docs 29001-29100
# 📦 Processed batch 292, docs 29101-29200
# 📦 Processed batch 293, docs 29201-29300
# 📦 Processed batch 294, docs 29301-29400
# 📦 Processed batch 295, docs 29401-29500
# 📦 Processed batch 296, docs 29501-29600
# 📦 Processed batch 297, docs 29601-29700
# 📦 Processed batch 298, docs 29701-29800
# 📦 Processed batch 299, docs 29801-29900
# 📦 Processed batch 300, docs 29901-30000
# 📦 Processed batch 301, docs 30001-30100
# 📦 Processed batch 302, docs 30101-30200
# 📦 Processed batch 303, docs 30201-30300
# 📦 Processed batch 304, docs 30301-30400
# 📦 Processed batch 305, docs 30401-30500
# 📦 Processed batch 306, docs 30501-30600
# 📦 Processed batch 307, docs 30601-30700
# 📦 Processed batch 308, docs 30701-30800
# 📦 Processed batch 309, docs 30801-30900
# 📦 Processed batch 310, docs 30901-31000
# 📦 Processed batch 311, docs 31001-31100
# 📦 Processed batch 312, docs 31101-31200
# 📦 Processed batch 313, docs 31201-31300
# 📦 Processed batch 314, docs 31301-31400
# 📦 Processed batch 315, docs 31401-31500
# 📦 Processed batch 316, docs 31501-31600
# 📦 Processed batch 317, docs 31601-31700
# 📦 Processed batch 318, docs 31701-31800
# 📦 Processed batch 319, docs 31801-31900
# 📦 Processed batch 320, docs 31901-32000
# 📦 Processed batch 321, docs 32001-32100
# 📦 Processed batch 322, docs 32101-32200
# 📦 Processed batch 323, docs 32201-32300
# 📦 Processed batch 324, docs 32301-32400
# 📦 Processed batch 325, docs 32401-32500
# 📦 Processed batch 326, docs 32501-32600
# 📦 Processed batch 327, docs 32601-32700
# 📦 Processed batch 328, docs 32701-32800
# 📦 Processed batch 329, docs 32801-32900
# 📦 Processed batch 330, docs 32901-33000
# 📦 Processed batch 331, docs 33001-33100
# 📦 Processed batch 332, docs 33101-33200
# 📦 Processed batch 333, docs 33201-33300
# 📦 Processed batch 334, docs 33301-33400
# 📦 Processed batch 335, docs 33401-33500
# 📦 Processed batch 336, docs 33501-33600
# 📦 Processed batch 337, docs 33601-33700
# 📦 Processed batch 338, docs 33701-33800
# 📦 Processed batch 339, docs 33801-33900
# 📦 Processed batch 340, docs 33901-34000
# 📦 Processed batch 341, docs 34001-34100
# 📦 Processed batch 342, docs 34101-34200
# 📦 Processed batch 343, docs 34201-34300
# 📦 Processed batch 344, docs 34301-34400
# 📦 Processed batch 345, docs 34401-34500
# 📦 Processed batch 346, docs 34501-34600
# 📦 Processed batch 347, docs 34601-34700
# 📦 Processed batch 348, docs 34701-34800
# 📦 Processed batch 349, docs 34801-34900
# 📦 Processed batch 350, docs 34901-35000
# 📦 Processed batch 351, docs 35001-35100
# 📦 Processed batch 352, docs 35101-35200
# 📦 Processed batch 353, docs 35201-35300
# 📦 Processed batch 354, docs 35301-35400
# 📦 Processed batch 355, docs 35401-35500
# 📦 Processed batch 356, docs 35501-35600
# 📦 Processed batch 357, docs 35601-35700
# 📦 Processed batch 358, docs 35701-35800
# 📦 Processed batch 359, docs 35801-35900
# 📦 Processed batch 360, docs 35901-36000
# 📦 Processed batch 361, docs 36001-36100
# 📦 Processed batch 362, docs 36101-36200
# 📦 Processed batch 363, docs 36201-36300
# 📦 Processed batch 364, docs 36301-36400
# 📦 Processed batch 365, docs 36401-36500
# 📦 Processed batch 366, docs 36501-36600
# 📦 Processed batch 367, docs 36601-36700
# 📦 Processed batch 368, docs 36701-36800
# 📦 Processed batch 369, docs 36801-36900
# 📦 Processed batch 370, docs 36901-37000
# 📦 Processed batch 371, docs 37001-37100
# 📦 Processed batch 372, docs 37101-37200
# 📦 Processed batch 373, docs 37201-37300
# 📦 Processed batch 374, docs 37301-37400
# 📦 Processed batch 375, docs 37401-37500
# 📦 Processed batch 376, docs 37501-37600
# 📦 Processed batch 377, docs 37601-37700
# 📦 Processed batch 378, docs 37701-37800
# 📦 Processed batch 379, docs 37801-37900
# 📦 Processed batch 380, docs 37901-38000
# 📦 Processed batch 381, docs 38001-38100
# 📦 Processed batch 382, docs 38101-38200
# 📦 Processed batch 383, docs 38201-38300
# 📦 Processed batch 384, docs 38301-38400
# 📦 Processed batch 385, docs 38401-38500
# 📦 Processed batch 386, docs 38501-38600
# 📦 Processed batch 387, docs 38601-38700
# 📦 Processed batch 388, docs 38701-38800
# 📦 Processed batch 389, docs 38801-38900
# 📦 Processed batch 390, docs 38901-39000
# 📦 Processed batch 391, docs 39001-39100
# 📦 Processed batch 392, docs 39101-39200
# 📦 Processed batch 393, docs 39201-39300
# 📦 Processed batch 394, docs 39301-39400
# 📦 Processed batch 395, docs 39401-39500
# 📦 Processed batch 396, docs 39501-39600
# 📦 Processed batch 397, docs 39601-39700
# 📦 Processed batch 398, docs 39701-39800
# 📦 Processed batch 399, docs 39801-39900
# 📦 Processed batch 400, docs 39901-40000
# 📦 Processed batch 401, docs 40001-40100
# 📦 Processed batch 402, docs 40101-40200
# 📦 Processed batch 403, docs 40201-40300
# 📦 Processed batch 404, docs 40301-40400
# 📦 Processed batch 405, docs 40401-40500
# 📦 Processed batch 406, docs 40501-40600
# 📦 Processed batch 407, docs 40601-40700
# 📦 Processed batch 408, docs 40701-40800
# 📦 Processed batch 409, docs 40801-40900
# 📦 Processed batch 410, docs 40901-41000
# 📦 Processed batch 411, docs 41001-41100
# 📦 Processed batch 412, docs 41101-41200
# 📦 Processed batch 413, docs 41201-41300
# 📦 Processed batch 414, docs 41301-41400
# 📦 Processed batch 415, docs 41401-41500
# 📦 Processed batch 416, docs 41501-41600
# 📦 Processed batch 417, docs 41601-41700
# 📦 Processed batch 418, docs 41701-41800
# 📦 Processed batch 419, docs 41801-41900
# 📦 Processed batch 420, docs 41901-42000
# 📦 Processed batch 421, docs 42001-42100
# 📦 Processed batch 422, docs 42101-42200
# 📦 Processed batch 423, docs 42201-42300
# 📦 Processed batch 424, docs 42301-42400
# 📦 Processed batch 425, docs 42401-42500
# 📦 Processed batch 426, docs 42501-42600
# 📦 Processed batch 427, docs 42601-42700
# 📦 Processed batch 428, docs 42701-42800
# 📦 Processed batch 429, docs 42801-42900
# 📦 Processed batch 430, docs 42901-43000
# 📦 Processed batch 431, docs 43001-43100
# 📦 Processed batch 432, docs 43101-43200
# 📦 Processed batch 433, docs 43201-43300
# 📦 Processed batch 434, docs 43301-43400
# 📦 Processed batch 435, docs 43401-43500
# 📦 Processed batch 436, docs 43501-43600
# 📦 Processed batch 437, docs 43601-43700
# 📦 Processed batch 438, docs 43701-43800
# 📦 Processed batch 439, docs 43801-43900
# 📦 Processed batch 440, docs 43901-44000
# 📦 Processed batch 441, docs 44001-44100
# 📦 Processed batch 442, docs 44101-44200
# 📦 Processed batch 443, docs 44201-44300
# 📦 Processed batch 444, docs 44301-44400
# 📦 Processed batch 445, docs 44401-44500
# 📦 Processed batch 446, docs 44501-44600
# 📦 Processed batch 447, docs 44601-44700
# 📦 Processed batch 448, docs 44701-44800
# 📦 Processed batch 449, docs 44801-44900
# 📦 Processed batch 450, docs 44901-45000
# 📦 Processed batch 451, docs 45001-45100
# 📦 Processed batch 452, docs 45101-45200
# 📦 Processed batch 453, docs 45201-45300
# 📦 Processed batch 454, docs 45301-45400
# 📦 Processed batch 455, docs 45401-45500
# 📦 Processed batch 456, docs 45501-45600
# 📦 Processed batch 457, docs 45601-45700
# 📦 Processed batch 458, docs 45701-45800
# 📦 Processed batch 459, docs 45801-45900
# 📦 Processed batch 460, docs 45901-46000
# 📦 Processed batch 461, docs 46001-46100
# 📦 Processed batch 462, docs 46101-46200
# 📦 Processed batch 463, docs 46201-46300
# 📦 Processed batch 464, docs 46301-46400
# 📦 Processed batch 465, docs 46401-46500
# 📦 Processed batch 466, docs 46501-46600
# 📦 Processed batch 467, docs 46601-46700
# 📦 Processed batch 468, docs 46701-46800
# 📦 Processed batch 469, docs 46801-46900
# 📦 Processed batch 470, docs 46901-47000
# 📦 Processed batch 471, docs 47001-47100
# 📦 Processed batch 472, docs 47101-47200
# 📦 Processed batch 473, docs 47201-47300
# 📦 Processed batch 474, docs 47301-47400
# 📦 Processed batch 475, docs 47401-47500
# 📦 Processed batch 476, docs 47501-47600
# 📦 Processed batch 477, docs 47601-47700
# 📦 Processed batch 478, docs 47701-47800
# 📦 Processed batch 479, docs 47801-47900
# 📦 Processed batch 480, docs 47901-48000
# 📦 Processed batch 481, docs 48001-48100
# 📦 Processed batch 482, docs 48101-48200
# 📦 Processed batch 483, docs 48201-48300
# 📦 Processed batch 484, docs 48301-48400
# 📦 Processed batch 485, docs 48401-48500
# 📦 Processed batch 486, docs 48501-48600
# 📦 Processed batch 487, docs 48601-48700
# 📦 Processed batch 488, docs 48701-48800
# 📦 Processed batch 489, docs 48801-48900
# 📦 Processed batch 490, docs 48901-49000
# 📦 Processed batch 491, docs 49001-49100
# 📦 Processed batch 492, docs 49101-49200
# 📦 Processed batch 493, docs 49201-49300
# 📦 Processed batch 494, docs 49301-49400
# 📦 Processed batch 495, docs 49401-49500
# 📦 Processed batch 496, docs 49501-49600
# 📦 Processed batch 497, docs 49601-49700
# 📦 Processed batch 498, docs 49701-49800
# 📦 Processed batch 499, docs 49801-49900
# 📦 Processed batch 500, docs 49901-50000
#
# 🔄 Testing batch size: 500
# ⚡ Testing bulk indexing with batch size 500, max docs 50000...
# 📦 Processed batch 1, docs 1-500
# 📦 Processed batch 2, docs 501-1000
# 📦 Processed batch 3, docs 1001-1500
# 📦 Processed batch 4, docs 1501-2000
# 📦 Processed batch 5, docs 2001-2500
# 📦 Processed batch 6, docs 2501-3000
# 📦 Processed batch 7, docs 3001-3500
# 📦 Processed batch 8, docs 3501-4000
# 📦 Processed batch 9, docs 4001-4500
# 📦 Processed batch 10, docs 4501-5000
# 📦 Processed batch 11, docs 5001-5500
# 📦 Processed batch 12, docs 5501-6000
# 📦 Processed batch 13, docs 6001-6500
# 📦 Processed batch 14, docs 6501-7000
# 📦 Processed batch 15, docs 7001-7500
# 📦 Processed batch 16, docs 7501-8000
# 📦 Processed batch 17, docs 8001-8500
# 📦 Processed batch 18, docs 8501-9000
# 📦 Processed batch 19, docs 9001-9500
# 📦 Processed batch 20, docs 9501-10000
# 📦 Processed batch 21, docs 10001-10500
# 📦 Processed batch 22, docs 10501-11000
# 📦 Processed batch 23, docs 11001-11500
# 📦 Processed batch 24, docs 11501-12000
# 📦 Processed batch 25, docs 12001-12500
# 📦 Processed batch 26, docs 12501-13000
# 📦 Processed batch 27, docs 13001-13500
# 📦 Processed batch 28, docs 13501-14000
# 📦 Processed batch 29, docs 14001-14500
# 📦 Processed batch 30, docs 14501-15000
# 📦 Processed batch 31, docs 15001-15500
# 📦 Processed batch 32, docs 15501-16000
# 📦 Processed batch 33, docs 16001-16500
# 📦 Processed batch 34, docs 16501-17000
# 📦 Processed batch 35, docs 17001-17500
# 📦 Processed batch 36, docs 17501-18000
# 📦 Processed batch 37, docs 18001-18500
# 📦 Processed batch 38, docs 18501-19000
# 📦 Processed batch 39, docs 19001-19500
# 📦 Processed batch 40, docs 19501-20000
# 📦 Processed batch 41, docs 20001-20500
# 📦 Processed batch 42, docs 20501-21000
# 📦 Processed batch 43, docs 21001-21500
# 📦 Processed batch 44, docs 21501-22000
# 📦 Processed batch 45, docs 22001-22500
# 📦 Processed batch 46, docs 22501-23000
# 📦 Processed batch 47, docs 23001-23500
# 📦 Processed batch 48, docs 23501-24000
# 📦 Processed batch 49, docs 24001-24500
# 📦 Processed batch 50, docs 24501-25000
# 📦 Processed batch 51, docs 25001-25500
# 📦 Processed batch 52, docs 25501-26000
# 📦 Processed batch 53, docs 26001-26500
# 📦 Processed batch 54, docs 26501-27000
# 📦 Processed batch 55, docs 27001-27500
# 📦 Processed batch 56, docs 27501-28000
# 📦 Processed batch 57, docs 28001-28500
# 📦 Processed batch 58, docs 28501-29000
# 📦 Processed batch 59, docs 29001-29500
# 📦 Processed batch 60, docs 29501-30000
# 📦 Processed batch 61, docs 30001-30500
# 📦 Processed batch 62, docs 30501-31000
# 📦 Processed batch 63, docs 31001-31500
# 📦 Processed batch 64, docs 31501-32000
# 📦 Processed batch 65, docs 32001-32500
# 📦 Processed batch 66, docs 32501-33000
# 📦 Processed batch 67, docs 33001-33500
# 📦 Processed batch 68, docs 33501-34000
# 📦 Processed batch 69, docs 34001-34500
# 📦 Processed batch 70, docs 34501-35000
# 📦 Processed batch 71, docs 35001-35500
# 📦 Processed batch 72, docs 35501-36000
# 📦 Processed batch 73, docs 36001-36500
# 📦 Processed batch 74, docs 36501-37000
# 📦 Processed batch 75, docs 37001-37500
# 📦 Processed batch 76, docs 37501-38000
# 📦 Processed batch 77, docs 38001-38500
# 📦 Processed batch 78, docs 38501-39000
# 📦 Processed batch 79, docs 39001-39500
# 📦 Processed batch 80, docs 39501-40000
# 📦 Processed batch 81, docs 40001-40500
# 📦 Processed batch 82, docs 40501-41000
# 📦 Processed batch 83, docs 41001-41500
# 📦 Processed batch 84, docs 41501-42000
# 📦 Processed batch 85, docs 42001-42500
# 📦 Processed batch 86, docs 42501-43000
# 📦 Processed batch 87, docs 43001-43500
# 📦 Processed batch 88, docs 43501-44000
# 📦 Processed batch 89, docs 44001-44500
# 📦 Processed batch 90, docs 44501-45000
# 📦 Processed batch 91, docs 45001-45500
# 📦 Processed batch 92, docs 45501-46000
# 📦 Processed batch 93, docs 46001-46500
# 📦 Processed batch 94, docs 46501-47000
# 📦 Processed batch 95, docs 47001-47500
# 📦 Processed batch 96, docs 47501-48000
# 📦 Processed batch 97, docs 48001-48500
# 📦 Processed batch 98, docs 48501-49000
# 📦 Processed batch 99, docs 49001-49500
# 📦 Processed batch 100, docs 49501-50000
#
# 🔄 Testing batch size: 1000
# ⚡ Testing bulk indexing with batch size 1000, max docs 50000...
# 📦 Processed batch 1, docs 1-1000
# 📦 Processed batch 2, docs 1001-2000
# 📦 Processed batch 3, docs 2001-3000
# 📦 Processed batch 4, docs 3001-4000
# 📦 Processed batch 5, docs 4001-5000
# 📦 Processed batch 6, docs 5001-6000
# 📦 Processed batch 7, docs 6001-7000
# 📦 Processed batch 8, docs 7001-8000
# 📦 Processed batch 9, docs 8001-9000
# 📦 Processed batch 10, docs 9001-10000
# 📦 Processed batch 11, docs 10001-11000
# 📦 Processed batch 12, docs 11001-12000
# 📦 Processed batch 13, docs 12001-13000
# 📦 Processed batch 14, docs 13001-14000
# 📦 Processed batch 15, docs 14001-15000
# 📦 Processed batch 16, docs 15001-16000
# 📦 Processed batch 17, docs 16001-17000
# 📦 Processed batch 18, docs 17001-18000
# 📦 Processed batch 19, docs 18001-19000
# 📦 Processed batch 20, docs 19001-20000
# 📦 Processed batch 21, docs 20001-21000
# 📦 Processed batch 22, docs 21001-22000
# 📦 Processed batch 23, docs 22001-23000
# 📦 Processed batch 24, docs 23001-24000
# 📦 Processed batch 25, docs 24001-25000
# 📦 Processed batch 26, docs 25001-26000
# 📦 Processed batch 27, docs 26001-27000
# 📦 Processed batch 28, docs 27001-28000
# 📦 Processed batch 29, docs 28001-29000
# 📦 Processed batch 30, docs 29001-30000
# 📦 Processed batch 31, docs 30001-31000
# 📦 Processed batch 32, docs 31001-32000
# 📦 Processed batch 33, docs 32001-33000
# 📦 Processed batch 34, docs 33001-34000
# 📦 Processed batch 35, docs 34001-35000
# 📦 Processed batch 36, docs 35001-36000
# 📦 Processed batch 37, docs 36001-37000
# 📦 Processed batch 38, docs 37001-38000
# 📦 Processed batch 39, docs 38001-39000
# 📦 Processed batch 40, docs 39001-40000
# 📦 Processed batch 41, docs 40001-41000
# 📦 Processed batch 42, docs 41001-42000
# 📦 Processed batch 43, docs 42001-43000
# 📦 Processed batch 44, docs 43001-44000
# 📦 Processed batch 45, docs 44001-45000
# 📦 Processed batch 46, docs 45001-46000
# 📦 Processed batch 47, docs 46001-47000
# 📦 Processed batch 48, docs 47001-48000
# 📦 Processed batch 49, docs 48001-49000
# 📦 Processed batch 50, docs 49001-50000
#
# 🔄 Testing batch size: 2000
# ⚡ Testing bulk indexing with batch size 2000, max docs 50000...
# 📦 Processed batch 1, docs 1-2000
# 📦 Processed batch 2, docs 2001-4000
# 📦 Processed batch 3, docs 4001-6000
# 📦 Processed batch 4, docs 6001-8000
# 📦 Processed batch 5, docs 8001-10000
# 📦 Processed batch 6, docs 10001-12000
# 📦 Processed batch 7, docs 12001-14000
# 📦 Processed batch 8, docs 14001-16000
# 📦 Processed batch 9, docs 16001-18000
# 📦 Processed batch 10, docs 18001-20000
# 📦 Processed batch 11, docs 20001-22000
# 📦 Processed batch 12, docs 22001-24000
# 📦 Processed batch 13, docs 24001-26000
# 📦 Processed batch 14, docs 26001-28000
# 📦 Processed batch 15, docs 28001-30000
# 📦 Processed batch 16, docs 30001-32000
# 📦 Processed batch 17, docs 32001-34000
# 📦 Processed batch 18, docs 34001-36000
# 📦 Processed batch 19, docs 36001-38000
# 📦 Processed batch 20, docs 38001-40000
# 📦 Processed batch 21, docs 40001-42000
# 📦 Processed batch 22, docs 42001-44000
# 📦 Processed batch 23, docs 44001-46000
# 📦 Processed batch 24, docs 46001-48000
# 📦 Processed batch 25, docs 48001-50000
#
# 🔄 Testing batch size: 5000
# ⚡ Testing bulk indexing with batch size 5000, max docs 50000...
# 📦 Processed batch 1, docs 1-5000
# 📦 Processed batch 2, docs 5001-10000
# 📦 Processed batch 3, docs 10001-15000
# 📦 Processed batch 4, docs 15001-20000
# 📦 Processed batch 5, docs 20001-25000
# 📦 Processed batch 6, docs 25001-30000
# 📦 Processed batch 7, docs 30001-35000
# 📦 Processed batch 8, docs 35001-40000
# 📦 Processed batch 9, docs 40001-45000
# 📦 Processed batch 10, docs 45001-50000
#
# 🔄 Testing batch size: 10000
# ⚡ Testing bulk indexing with batch size 10000, max docs 50000...
# 📦 Processed batch 1, docs 1-10000
# 📦 Processed batch 2, docs 10001-20000
# 📦 Processed batch 3, docs 20001-30000
# 📦 Processed batch 4, docs 30001-40000
# 📦 Processed batch 5, docs 40001-50000
#
# 🔄 Testing batch size: 20000
# ⚡ Testing bulk indexing with batch size 20000, max docs 50000...
# 📦 Processed batch 1, docs 1-20000
# 📦 Processed batch 2, docs 20001-40000
# 📦 Processed batch 3, docs 40001-50000
#
# ============================================================
# 📊 PERFORMANCE RESULTS
# ============================================================
#             method  duration  docs_per_second  errors  total_docs  batch_size
#         Individual 27.237795       183.568458       0        5000         NaN
#   Bulk (batch=100)  5.405250      9250.265413       0       50000       100.0
#   Bulk (batch=500)  3.285793     15217.027556       0       50000       500.0
#  Bulk (batch=1000)  2.981292     16771.252143       0       50000      1000.0
#  Bulk (batch=2000)  3.482125     14359.048797       0       50000      2000.0
#  Bulk (batch=5000)  2.924841     17094.946784       0       50000      5000.0
# Bulk (batch=10000)  3.304380     15131.429706       0       50000     10000.0
# Bulk (batch=20000)  2.944340     16981.733125       0       50000     20000.0
#
# 🏆 Best Performance: Bulk (batch=5000)
# 📈 17094.95 docs/second

# %% [markdown]
# ## 📊 Step 7: Visualize Performance Results

# %%
# Create visualization of performance results
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('🚀 OpenSearch Bulk API Performance Analysis', fontsize=16, fontweight='bold')

# 1. Documents per second comparison
ax1 = axes[0, 0]
methods = [r['method'] for r in results]
speeds = [r['docs_per_second'] for r in results]
colors = ['#ff9999' if 'Individual' in m else '#66b3ff' for m in methods]

bars1 = ax1.bar(range(len(methods)), speeds, color=colors)
ax1.set_title('📈 Indexing Speed (docs/second)', fontweight='bold')
ax1.set_ylabel('Documents/Second')
ax1.set_xticks(range(len(methods)))
ax1.set_xticklabels(methods, rotation=45, ha='right')

# Add value labels on bars
for bar, speed in zip(bars1, speeds):
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2., height + 0.1,
             f'{speed:.1f}', ha='center', va='bottom')

# 2. Total duration comparison
ax2 = axes[0, 1]
durations = [r['duration'] for r in results]
bars2 = ax2.bar(range(len(methods)), durations, color=colors)
ax2.set_title('⏱️ Total Duration (seconds)', fontweight='bold')
ax2.set_ylabel('Duration (seconds)')
ax2.set_xticks(range(len(methods)))
ax2.set_xticklabels(methods, rotation=45, ha='right')

# Add value labels
for bar, duration in zip(bars2, durations):
    height = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2., height + 0.1,
             f'{duration:.1f}s', ha='center', va='bottom')

# 3. Batch size vs performance (bulk only)
ax3 = axes[1, 0]
bulk_results = [r for r in results if 'Bulk' in r['method']]
if bulk_results:
    batch_sizes_plot = [r['batch_size'] for r in bulk_results]
    speeds_bulk = [r['docs_per_second'] for r in bulk_results]
    ax3.plot(batch_sizes_plot, speeds_bulk, 'o-', linewidth=2, markersize=8, color='#66b3ff')
    ax3.set_title('🎯 Batch Size vs Performance', fontweight='bold')
    ax3.set_xlabel('Batch Size')
    ax3.set_ylabel('Documents/Second')
    ax3.grid(True, alpha=0.3)

# 4. Error rate comparison
ax4 = axes[1, 1]
error_rates = [r['errors'] / r['total_docs'] * 100 for r in results]
bars4 = ax4.bar(range(len(methods)), error_rates, color=['#ffcccc' if e > 0 else '#ccffcc' for e in error_rates])
ax4.set_title('❌ Error Rate (%)', fontweight='bold')
ax4.set_ylabel('Error Rate (%)')
ax4.set_xticks(range(len(methods)))
ax4.set_xticklabels(methods, rotation=45, ha='right')

plt.tight_layout()
plt.show()

# Print performance summary
print("\n" + "="*60)
print("🎯 PERFORMANCE SUMMARY")
print("="*60)

individual_speed = results[0]['docs_per_second']
best_bulk_speed = max([r['docs_per_second'] for r in results if 'Bulk' in r['method']])
improvement = ((best_bulk_speed - individual_speed) / individual_speed) * 100

print(f"🐌 Individual indexing: {individual_speed:.1f} docs/second")
print(f"⚡ Best bulk indexing: {best_bulk_speed:.1f} docs/second")
print(f"📈 Performance improvement: {improvement:.1f}%")
print(f"🏆 Optimal batch size: {best_result['batch_size']} documents")
# Out:
# ============================================================
# 🎯 PERFORMANCE SUMMARY
# ============================================================
# 🐌 Individual indexing: 183.6 docs/second
# ⚡ Best bulk indexing: 17094.9 docs/second
# 📈 Performance improvement: 9212.6%
# 🏆 Optimal batch size: 5000 documents

# %% [markdown]
# ## 🔄 Step 8: Asynchronous Bulk Processing

# %%
async def async_bulk_indexing(documents, batch_size=5000, max_docs=50000):
    """Test asynchronous bulk indexing performance"""
    start_time = time.time()
    total_errors = 0
    
    print(f"🚀 Testing async bulk indexing with batch size {batch_size}...")
    
    # Prepare documents
    bulk_docs = []
    for i, doc in enumerate(documents[:max_docs]):
        doc['_id'] = f"async_{i}"
        bulk_docs.append(doc)
    
    # Process batches asynchronously
    tasks = []
    for i in range(0, len(bulk_docs), batch_size):
        batch = bulk_docs[i:i + batch_size]
        task = asyncio.create_task(process_async_batch(batch, i//batch_size + 1))
        tasks.append(task)
    
    # Wait for all tasks to complete
    results = await asyncio.gather(*tasks, return_exceptions=True)
    
    # Count errors
    for result in results:
        if isinstance(result, Exception):
            total_errors += 1
            print(f"❌ Batch error: {str(result)[:100]}...")
        elif isinstance(result, dict) and 'errors' in result:
            total_errors += result['errors']
    
    end_time = time.time()
    duration = end_time - start_time
    
    return {
        'method': f'Async Bulk (batch={batch_size})',
        'duration': duration,
        'docs_per_second': len(bulk_docs) / duration,
        'errors': total_errors,
        'total_docs': len(bulk_docs),
        'batch_size': batch_size
    }

async def process_async_batch(batch, batch_num):
    """Process a single batch asynchronously"""
    try:
        response = await helpers.async_bulk(async_client, batch, refresh=False)
        errors = len(response[1]) if response[1] else 0
        print(f"📦 Async batch {batch_num} completed: {len(batch)} docs, {errors} errors")
        return {'errors': errors}
    except Exception as e:
        print(f"❌ Async batch {batch_num} failed: {str(e)[:100]}...")
        return {'errors': len(batch)}

# Run async test
print("🔄 Starting asynchronous bulk indexing test...")
async_result = await async_bulk_indexing(test_docs, batch_size=5000, max_docs=50000)

print(f"\n⚡ Async Results:")
print(f"📈 Speed: {async_result['docs_per_second']:.1f} docs/second")
print(f"⏱️ Duration: {async_result['duration']:.2f} seconds")
print(f"❌ Errors: {async_result['errors']}")

# Compare with best sync result
if best_result:
    async_improvement = ((async_result['docs_per_second'] - best_result['docs_per_second']) / best_result['docs_per_second']) * 100
    print(f"🚀 Async vs Best Sync improvement: {async_improvement:.1f}%")
# Out:
# 🔄 Starting asynchronous bulk indexing test...
# 🚀 Testing async bulk indexing with batch size 5000...
# 📦 Async batch 5 completed: 5000 docs, 0 errors
# 📦 Async batch 2 completed: 5000 docs, 0 errors
# 📦 Async batch 6 completed: 5000 docs, 0 errors
# 📦 Async batch 7 completed: 5000 docs, 0 errors
# 📦 Async batch 10 completed: 5000 docs, 0 errors
# 📦 Async batch 1 completed: 5000 docs, 0 errors
# 📦 Async batch 4 completed: 5000 docs, 0 errors
# 📦 Async batch 8 completed: 5000 docs, 0 errors
# 📦 Async batch 9 completed: 5000 docs, 0 errors
# 📦 Async batch 3 completed: 5000 docs, 0 errors
#
# ⚡ Async Results:
# 📈 Speed: 51452.8 docs/second
# ⏱️ Duration: 0.97 seconds
# ❌ Errors: 0
# 🚀 Async vs Best Sync improvement: 201.0%

# %% [markdown]
# ## 🎯 Step 9: Key Takeaways and Best Practices

# %% [markdown]
# ### 🏆 Performance Summary
#
# Based on our testing with the SQUAD dataset:
#
# #### ✅ **What We Learned:**
# 1. **Bulk API is significantly faster** than individual document indexing
# 2. **Optimal batch size matters** - too small wastes overhead, too large causes memory issues
# 3. **Asynchronous processing** can provide additional performance gains
# 4. **Index settings** like refresh interval and translog size impact performance
#
# #### 🎯 **Best Practices:**
# 1. **Always use bulk API** for multiple documents
# 2. **Start with 1000 document batches**, tune based on your data
# 3. **Use async clients** for high-throughput scenarios
# 4. **Monitor for 429 errors** and implement exponential backoff
# 5. **Adjust refresh interval** to reduce indexing overhead
# 6. **Set appropriate translog flush thresholds**
#
# #### 🔧 **Next Steps:**
# - Test with your actual data structure
# - Monitor cluster metrics during ingestion
# - Experiment with different batch sizes
# - Implement error handling and retry logic

# %%
# Cleanup: Close connections
try:
    await async_client.close()
    print("✅ Closed async client connection")
except:
    pass

# Check final index stats
try:
    stats = client.indices.stats(index=index_name)
    total_docs = stats['indices'][index_name]['total']['docs']['count']
    index_size = stats['indices'][index_name]['total']['store']['size_in_bytes']
    print(f"\n📊 Final Index Stats:")
    print(f"📄 Total documents: {total_docs:,}")
    print(f"💾 Index size: {index_size / (1024*1024):.2f} MB")
except Exception as e:
    print(f"❌ Error getting stats: {e}")

print("\n🎉 Bulk API optimization demo completed!")
print("💡 Try running the other optimization notebooks to see compound effects!")

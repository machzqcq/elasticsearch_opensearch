# %% [markdown]
# # 📊 LogPatternTool - Extract Patterns from Log Data
#
# ```mermaid
# %%{init: {'theme':'base', 'themeVariables': { 'primaryColor':'#D35400', 'primaryTextColor':'#fff', 'primaryBorderColor':'#BA4A00', 'lineColor':'#F39C12', 'secondaryColor':'#3498DB', 'tertiaryColor':'#27AE60', 'fontSize':'16px'}}}%%
# graph TB
#     A[📋 Log Data] --> B[🤖 Flow Agent]
#     B --> C{🔍 LogPatternTool}
#     C --> D[📊 Sample Logs]
#     D --> E[🧠 Pattern Detection]
#     E --> F[🎯 Pattern Extraction]
#     F --> G[📈 Pattern Frequency]
#     G --> H[📋 Top N Patterns]
#
#     style A fill:#3498DB,stroke:#2980B9,color:#fff
#     style C fill:#D35400,stroke:#BA4A00,color:#fff
#     style E fill:#9B59B6,stroke:#8E44AD,color:#fff
#     style G fill:#E67E22,stroke:#D35400,color:#fff
#     style H fill:#27AE60,stroke:#229954,color:#fff
# ```
#
# ## 📚 Learning Objectives
#
# 1. ✅ Discover **recurring patterns** in log data automatically
# 2. ✅ Use **DSL or PPL queries** to extract logs
# 3. ✅ Configure **sample size** and **top N patterns**
# 4. ✅ Analyze **log templates** and **frequencies**
# 5. ✅ Identify **common issues** and **anomalies**
#
# ---
#
# ## 🎯 What is LogPatternTool?
#
# **LogPatternTool** automatically discovers patterns in unstructured log data:
# - 🔍 **Pattern Detection**: Finds recurring log templates
# - 📊 **Frequency Analysis**: Counts pattern occurrences
# - 🎯 **Anomaly Detection**: Identifies unusual patterns
# - 📈 **Trend Analysis**: Tracks pattern changes over time
#
# **Example**:
# ```
# Raw Logs:
#   "User john logged in from 192.168.1.1"
#   "User mary logged in from 192.168.1.5"
#   "User bob logged in from 192.168.1.8"
#
# Pattern Detected:
#   "User <*> logged in from <*>" (count: 3)
# ```
#
# ---

# %% [markdown]
# ## Step 1: Import Libraries

# %%
import sys
import json
from datetime import datetime

sys.path.append('..')
from agent_helpers import (
    get_os_client,
    create_flow_agent,
    execute_agent,
    cleanup_resources
)

print("✅ Libraries imported!")
# Out:
# ✅ Libraries imported!

# %% [markdown]
# ## Step 2: Initialize Client

# %%
client = get_os_client()
print("✅ Client ready")
# Out:
# ✅ Client ready

# %% [markdown]
# ## Step 3: Create Sample Log Index

# %%
index_name = "system_logs"

if client.indices.exists(index=index_name):
    client.indices.delete(index=index_name)

client.indices.create(index=index_name)

# Sample log messages with patterns
logs = [
    {"timestamp": "2025-11-09T10:00:00Z", "message": "User john logged in from 192.168.1.1"},
    {"timestamp": "2025-11-09T10:01:00Z", "message": "User mary logged in from 192.168.1.5"},
    {"timestamp": "2025-11-09T10:02:00Z", "message": "User bob logged in from 192.168.1.8"},
    {"timestamp": "2025-11-09T10:03:00Z", "message": "Database connection failed for host db01"},
    {"timestamp": "2025-11-09T10:04:00Z", "message": "Database connection failed for host db02"},
    {"timestamp": "2025-11-09T10:05:00Z", "message": "API request timeout after 30 seconds"},
    {"timestamp": "2025-11-09T10:06:00Z", "message": "API request timeout after 45 seconds"},
    {"timestamp": "2025-11-09T10:07:00Z", "message": "API request timeout after 60 seconds"},
    {"timestamp": "2025-11-09T10:08:00Z", "message": "Memory usage at 85% on server web01"},
    {"timestamp": "2025-11-09T10:09:00Z", "message": "Memory usage at 92% on server web02"},
]

for log in logs:
    client.index(index=index_name, body=log, refresh=True)

print(f"✅ Created {len(logs)} log entries")
# Out:
# ✅ Created 10 log entries

# %% [markdown]
# ## Step 4: Create Agent with LogPatternTool (DSL Query)

# %%
# DSL query to extract all logs
dsl_query = {
    "query": {"match_all": {}},
    "_source": ["message"]
}

tools = [{
    "type": "LogPatternTool",
    "parameters": {
        "sample_log_size": 100,
        "top_n_pattern": 5,
        "input": json.dumps(dsl_query)
    }
}]

agent_id = create_flow_agent(
    client, "Log_Pattern_Agent",
    "Discovers patterns in log data",
    tools
)
print(f"✅ Log pattern agent created: {agent_id}")
# Out:
#    Registering flow agent: Log_Pattern_Agent...
#    ✓ Agent registered: K4Fka5oBAjDPEnaCf5eP
# ✅ Log pattern agent created: K4Fka5oBAjDPEnaCf5eP

# %% [markdown]
# ## Step 5: Test Case 1 - Discover All Patterns

# %%
parameters = {"index": index_name}

print("🔍 Analyzing log patterns...")
print("="*60)
response = execute_agent(client, agent_id, parameters)
print("\n📊 Discovered Patterns:")
print(json.dumps(response, indent=2))
# Out:
# 🔍 Analyzing log patterns...
# ============================================================
#
# 📊 Discovered Patterns:
# {
#   "inference_results": [
#     {
#       "output": [
#         {
#           "name": "response",
#           "result": "[{\"pattern\":\"Database connection failed for host <*>\",\"sample logs\":[\"Database connection failed for host db01\",\"Database connection failed for host db02\"],\"total count\":2},{\"pattern\":\"User john logged in from <*IP*>\",\"sample logs\":[\"User john logged in from 192.168.1.1\"],\"total count\":1},{\"pattern\":\"Memory usage at 85% on server <*>\",\"sample logs\":[\"Memory usage at 85% on server web01\"],\"total count\":1},{\"pattern\":\"User bob logged in from <*IP*>\",\"sample logs\":[\"User bob logged in from 192.168.1.8\"],\"total count\":1},{\"pattern\":\"API request timeout after 60 seconds\",\"sample logs\":[\"API request timeout after 60 seconds\"],\"total count\":1}]"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Step 6: Create Agent with PPL Query

# %%
# PPL query to filter error logs
ppl_query = f"source={index_name} | where message like '%failed%' or message like '%timeout%'"

tools_ppl = [{
    "type": "LogPatternTool",
    "parameters": {
        "sample_log_size": 50,
        "top_n_pattern": 3,
        "input": ppl_query
    }
}]

agent_id_ppl = create_flow_agent(
    client, "Error_Pattern_Agent",
    "Finds patterns in error logs using PPL",
    tools_ppl
)
print(f"✅ Error pattern agent created: {agent_id_ppl}")
# Out:
#    Registering flow agent: Error_Pattern_Agent...
#    ✓ Agent registered: LIFka5oBAjDPEnaCwZf6
# ✅ Error pattern agent created: LIFka5oBAjDPEnaCwZf6

# %% [markdown]
# ## Step 7: Test Case 2 - Error Patterns Only

# %%
parameters = {"index": index_name}

print("🔍 Analyzing error patterns...")
print("="*60)
response = execute_agent(client, agent_id_ppl, parameters)
print("\n📊 Error Patterns:")
print(json.dumps(response, indent=2))
# Out:
# 🔍 Analyzing error patterns...
# ============================================================
# ---------------------------------------------------------------------------
# TransportError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 print("🔍 Analyzing error patterns...")
#       4 print("="*60)
# ----> 5 response = execute_agent(client, agent_id_ppl, parameters)
#       6 print("\n📊 Error Patterns:")
#       7 print(json.dumps(response, indent=2))
#
# File ~/git-projects/personal/github.com/elasticsearch_opensearch/5. AGENTIC_SEARCH/4. agents_tools/agent_helpers.py:260, in execute_agent(client, agent_id, parameters)
#     245 """
#     246 Execute an agent with given parameters.
#     247
#    (...)    254     dict: Agent execution response
#     255 """
#     256 execute_body = {
#     257     "parameters": parameters
#     258 }
# --> 260 response = client.transport.perform_request('POST', f'/_plugins/_ml/agents/{agent_id}/_execute', body=execute_body)
#     261 return response
#
# File ~/git-projects/personal/github.com/elasticsearch_opensearch/.venv/lib/python3.12/site-packages/opensearchpy/transport.py:457, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     455             raise e
#     456     else:
# --> 457         raise e
#     459 else:
#     460     # connection didn't fail, confirm its live status
#     461     self.connection_pool.mark_live(connection)
#
# File ~/git-projects/personal/github.com/elasticsearch_opensearch/.venv/lib/python3.12/site-packages/opensearchpy/transport.py:418, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     415 connection = self.get_connection()
#     417 try:
# --> 418     status, headers_response, data = connection.perform_request(
#     419         method,
#     420         url,
#     421         params,
#     422         body,
#     423         headers=headers,
#     424         ignore=ignore,
#     425         timeout=timeout,
#     426     )
#     428     # Lowercase all the header names for consistency in accessing them.
#     429     headers_response = {
#     430         header.lower(): value for header, value in headers_response.items()
#     431     }
#
# File ~/git-projects/personal/github.com/elasticsearch_opensearch/.venv/lib/python3.12/site-packages/opensearchpy/connection/http_urllib3.py:308, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     304 if not (200 <= response.status < 300) and response.status not in ignore:
#     305     self.log_request_fail(
#     306         method, full_url, url, orig_body, duration, response.status, raw_data
#     307     )
# --> 308     self._raise_error(
#     309         response.status,
#     310         raw_data,
#     311         self.get_response_headers(response).get("content-type"),
#     312     )
#     314 self.log_request_success(
#     315     method, full_url, url, orig_body, response.status, raw_data, duration
#     316 )
#     318 return response.status, response.headers, raw_data
#
# File ~/git-projects/personal/github.com/elasticsearch_opensearch/.venv/lib/python3.12/site-packages/opensearchpy/connection/base.py:315, in Connection._raise_error(self, status_code, raw_data, content_type)
#     312 except (ValueError, TypeError) as err:
#     313     logger.warning("Undecodable raw error response from server: %s", err)
# --> 315 raise HTTP_EXCEPTIONS.get(status_code, TransportError)(
#     316     status_code, error_message, additional_info
#     317 )
#
# TransportError: TransportError(500, 'JSONException')

# %% [markdown]
# ## Step 8: Add More Diverse Logs

# %%
# Add more varied logs
additional_logs = [
    {"timestamp": "2025-11-09T10:10:00Z", "message": "Disk space low on volume /dev/sda1"},
    {"timestamp": "2025-11-09T10:11:00Z", "message": "Disk space low on volume /dev/sdb1"},
    {"timestamp": "2025-11-09T10:12:00Z", "message": "Backup completed successfully in 120 seconds"},
    {"timestamp": "2025-11-09T10:13:00Z", "message": "Backup completed successfully in 135 seconds"},
    {"timestamp": "2025-11-09T10:14:00Z", "message": "User alice logged in from 10.0.0.15"},
]

for log in additional_logs:
    client.index(index=index_name, body=log, refresh=True)

print(f"✅ Added {len(additional_logs)} more logs")

# %% [markdown]
# ## Step 9: Test Case 3 - Updated Pattern Analysis

# %%
parameters = {"index": index_name}

print("🔍 Re-analyzing patterns with updated data...")
print("="*60)
response = execute_agent(client, agent_id, parameters)
print("\n📊 Updated Pattern Analysis:")
print(json.dumps(response, indent=2))

# %% [markdown]
# ## 🎓 Key Takeaways
#
# ### What We Learned:
#
# 1. **LogPatternTool Capabilities**:
#    - ✅ Automatically discovers recurring patterns
#    - ✅ Groups similar log messages
#    - ✅ Counts pattern frequencies
#    - ✅ Supports DSL and PPL queries
#
# 2. **Configuration Parameters**:
#    ```python
#    {
#        "type": "LogPatternTool",
#        "parameters": {
#            "sample_log_size": 100,    # Number of logs to analyze
#            "top_n_pattern": 5,         # Return top 5 patterns
#            "input": query              # DSL or PPL query
#        }
#    }
#    ```
#
# 3. **Query Types**:
#    ```python
#    # DSL Query
#    dsl_query = {
#        "query": {"match_all": {}},
#        "_source": ["message"]
#    }
#
#    # PPL Query
#    ppl_query = "source=logs | where level='ERROR' | fields message"
#    ```
#
# 4. **Pattern Examples**:
#    ```
#    Original Logs:
#      "User john logged in from 192.168.1.1"
#      "User mary logged in from 192.168.1.5"
#
#    Pattern:
#      "User <*> logged in from <*>"
#      Count: 2
#    ```
#
# 5. **Use Cases**:
#    - 🔍 **Troubleshooting**: Find recurring errors
#    - 📊 **Monitoring**: Track common events
#    - 🎯 **Anomaly Detection**: Identify unusual patterns
#    - 📈 **Trend Analysis**: Monitor pattern changes
#
# ### Common Patterns Discovered:
#
# | Pattern Template | Example Count | Meaning |
# |-----------------|---------------|----------|
# | User <*> logged in from <*> | 4 | Login events |
# | Database connection failed for host <*> | 2 | DB errors |
# | API request timeout after <*> seconds | 3 | Timeout issues |
# | Memory usage at <*>% on server <*> | 2 | Resource alerts |
#
# ### Best Practices:
#
# - ✅ **Sample Size**: Balance accuracy vs performance (50-1000 logs)
# - ✅ **Time Windows**: Analyze recent logs for current issues
# - ✅ **Top N**: Start with 5-10 patterns, adjust as needed
# - ✅ **Field Selection**: Use `_source` to specify message fields
# - ✅ **Filters**: Use PPL/DSL to focus on specific log types
#
# ### Combining with Other Tools:
#
# ```python
# # Complete log analysis pipeline
# tools = [
#     {"type": "LogPatternTool", ...},           # 1. Find patterns
#     {"type": "LogPatternAnalysisTool", ...},  # 2. Deep analysis
#     {"type": "MLModelTool", ...}              # 3. Explain findings
# ]
# ```
#
# ---

# %% [markdown]
# ## 🧹 Cleanup

# %%
# # cleanup_resources(
# #     client=client,
# #     agent_ids=[agent_id, agent_id_ppl]
# # )
# # client.indices.delete(index=index_name)
# # print("✅ Cleanup complete!")

# %% [markdown]
# ## 🚀 Next Steps
#
# - **LogPatternAnalysisTool**: Advanced pattern analysis
# - **PPLTool**: Custom log queries
# - **MLModelTool**: Explain pattern insights
#
# 📚 [LogPatternTool Documentation](https://opensearch.org/docs/latest/ml-commons-plugin/agents-tools/tools/log-pattern-tool/)
